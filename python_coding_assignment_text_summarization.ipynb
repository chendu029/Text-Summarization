# %% [markdown]
# <a href="https://colab.research.google.com/github/chendu029/Text-Summarization/blob/main/python_coding_assignment_text_summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import fitz  # PyMuPDF for PDF parsing
from transformers import pipeline
import pandas as pd
import PyPDF2
import re
import torch

# %%
# Check if GPU is available
device = 0 if torch.cuda.is_available() else -1  # Use GPU if available, else use CPU

def extract_text_from_pdf(pdf_path):
    """
    Extract text from each page of a PDF document.

    :param pdf_path: Path to the PDF file
    :return: Extracted text from the PDF
    """
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text("text")

    if not text.strip():  # Check if the text is empty or just whitespace
        raise ValueError("No text extracted from the PDF. Please check the document.")

    return text

# %%
def summarize_text_with_huggingface(text):
    """
    Use Hugging Face's pre-trained summarization model to extract key insights.

    :param text: Text extracted from PDF
    :return: Summary and key insights
    """
    # Load a summarization pipeline from Hugging Face
    summarizer = pipeline("summarization", model="facebook/bart-large-cnn", device=device)

    # Check if the text is too long for the model (max length for BART is typically 1024 tokens)
    max_chunk_size = 1024  # BART max token length
    chunk_size = len(text.split())

    # If text is too large, split into smaller chunks
    if chunk_size > max_chunk_size:
        chunks = [text[i:i+max_chunk_size] for i in range(0, len(text), max_chunk_size)]
    else:
        chunks = [text]

    # Process each chunk separately
    summaries = []
    for chunk in chunks:
        summary = summarizer(chunk, max_length=500, min_length=200, do_sample=False)
        summaries.append(summary[0]['summary_text'])

    # Combine the individual summaries into one
    full_summary = " ".join(summaries)

    # Format the summary for readability (split by sentences)
    formatted_summary = format_summary_readable(full_summary)

    return formatted_summary

# %%
def format_summary_readable(summary):
    """
    Format the summary to make it more readable by splitting it into individual sentences.

    :param summary: The summary text to format
    :return: Formatted summary with each sentence on a new line
    """
    # Split summary into sentences using a regular expression (you can adjust the regex to match your needs)
    sentences = re.split(r'(?<=\.)\s+', summary.strip())  # Split at periods followed by spaces

    # Join sentences with line breaks
    readable_summary = "\n".join(sentences)

    return readable_summary

# %%
def process_pdf_for_investor(pdf_path):
    """
    Extract text from a PDF and summarize key insights for an investor.

    :param pdf_path: Path to the PDF document
    :return: Summary with key points related to business growth, changes, and material effects
    """
    try:
        # Extract text from the PDF
        text = extract_text_from_pdf(pdf_path)

        # Use Hugging Face summarizer to extract relevant information for an investor
        summary = summarize_text_with_huggingface(text)

        return summary

    except ValueError as e:
        # Handle any errors that occur during text extraction or summarization
        return f"Error: {e}"

# %%
pdf_path = '/content/SJS Transcript Call.pdf'  # Replace with the path to your PDF file
summary = process_pdf_for_investor(pdf_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Your max_length is set to 500, but your input_length is only 389. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=194)
# Your max_length is set to 500, but your input_length is only 361. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=180)
# Your max_length is set to 500, but your input_length is only 283. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=141)
# Your max_length is set to 500, but your input_length is only 261. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=130)
# Your max_length is set to 500, but your input_length is only 226. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=113)
# Your max_length is set to 500, but your input_length is only 213. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=106)
# Your max_length is set to 500, but your input_length is only 272. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=136)
# Your max_length is set to 500, but your input_length is only 269. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=134)
# Your max_length is set to 500, but your input_length is only 231. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=115)
# Your max_length is set to 500, but your input_length is only 263. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=131)
# Your max_length is set to 500, but your input_length is only 263. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=131)
# Your max_length is set to 500, but your input_length is only 264. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=132)
# Your max_length is set to 500, but your input_length is only 276. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=138)
# Your max_length is set to 500, but your input_length is only 270. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=135)
# Your max_length is set to 500, but your input_length is only 216. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=108)
# Your max_length is set to 500, but your input_length is only 244. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=122)
# Your max_length is set to 500, but your input_length is only 226. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=113)
# Your max_length is set to 500, but your input_length is only 257. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=128)
# Your max_length is set to 500, but your input_length is only 271. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=135)
# Your max_length is set to 500, but your input_length is only 271. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=135)
# Your max_length is set to 500, but your input_length is only 255. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=127)
# Your max_length is set to 500, but your input_length is only 276. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=138)
# Your max_length is set to 500, but your input_length is only 278. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=139)
# Your max_length is set to 500, but your input_length is only 262. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=131)
# Your max_length is set to 500, but your input_length is only 280. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=140)
# Your max_length is set to 500, but your input_length is only 239. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# Your max_length is set to 500, but your input_length is only 268. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=134)
# Your max_length is set to 500, but your input_length is only 276. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=138)
# Your max_length is set to 500, but your input_length is only 239. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# Your max_length is set to 500, but your input_length is only 248. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=124)
# Your max_length is set to 500, but your input_length is only 256. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=128)
# Your max_length is set to 500, but your input_length is only 285. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=142)
# Your max_length is set to 500, but your input_length is only 243. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=121)
# Your max_length is set to 500, but your input_length is only 293. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=146)
# Your max_length is set to 500, but your input_length is only 258. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=129)
# Your max_length is set to 500, but your input_length is only 255. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=127)
# Your max_length is set to 500, but your input_length is only 306. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=153)
# Your max_length is set to 500, but your input_length is only 239. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# Your max_length is set to 500, but your input_length is only 242. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=121)
# Your max_length is set to 500, but your input_length is only 301. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=150)
# Your max_length is set to 500, but your input_length is only 262. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=131)
# Your max_length is set to 500, but your input_length is only 278. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=139)
# Your max_length is set to 500, but your input_length is only 247. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=123)
# Your max_length is set to 500, but your input_length is only 259. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=129)
# Your max_length is set to 500, but your input_length is only 253. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=126)
# Your max_length is set to 500, but your input_length is only 265. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=132)
# Your max_length is set to 500, but your input_length is only 252. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=126)
# Your max_length is set to 500, but your input_length is only 273. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=136)
# Your max_length is set to 500, but your input_length is only 278. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=139)
# Your max_length is set to 500, but your input_length is only 266. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=133)
# Your max_length is set to 500, but your input_length is only 121. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)

# %%
print(summary)
# Out:
# Transcripts of Analysts/Investor Meet/ Earnings Call of the Company pertaining to Q1 of FY 2023-24 held on July 27, 2023.
# S.J.S.
# Enterprises Limited.
# The call was held at 11:16:51 +05'30' at the National Stock Exchange of India (NSE) in Mumbai.
# The transcript of the call has been sent to Mr.
# Thabraz Hushain W.
# Ahmed, Company Secretary and Compliance Officer, NSE.
# For confidential support call the Samaritans on 08457 90 90 90 or visit a local Samaritans branch, see www.samaritans.org for details.
# In the U.S., call the National Suicide Prevention Line on 1-800-273-8255 or visit http://www.suicidepreventionlifeline.org/.
# For confidential.
# support in the UK, call the 08457 909090 or visit the Samaritans’ website: http: www.
# Samaritans.co.uk.
# The conference call is being hosted by JM Financial.
# All participant lines will be in the listen-only mode.
# Should you need assistance, please signal an operator by pressing ‘*’ then ‘0’ on a touchtone phone.
# The conference is being recorded.
# The call is expected to be recorded and will be available for playback after the presentation concludes.
# The company's name is SJS.
# prises Limited and the company is based in Sydney, Australia.
# The firm has a turnover of $1.2 billion and has a market capitalization of $7.1 billion.
# It has been listed on the Australian Securities Exchange since April 1, 2013.
# The stock price of the company has been trading at $2.01 per share since April 2, 2014.
# It is expected that the share price will rise to $3.05 per share by the end of the year.
# The share price is currently trading at around $2 per share.
# The market value of SJS has risen to $2 billion since the beginning of the first quarter.
# Mr.
# K A Joseph – Managing Director and Co-Founder; Mr.
# Sanjay Thapar - CEO and Executive Director.
# Mr.
# Mahendra                  Naredi - Chief Financial Officer and Ms.
# Devanshi Dhruva – Head, Investor Relations.
# We will start the call with brief opening remarks from the management, followed by a Q&A session.
# Thank you, Ronak.
# l Securities, I welcome you all to 1Q FY24 Earnings Call of SJS  CarbuncleEnterprises.
# The call is being webcast live on SJS' website and will be available for replay on the SJS Investor Relations website.
# We are happy to provide you with any additional information about SJS or our acquisition of Walter Pack India's Performance, if you would like to follow up on this.
# Please visit SJS investor relations website at: www.sjinvestorrelations.com.
# For more information, please visit: http://www.sjs.com/investor-relations.
# The duration of this call will be around 60 minutes and we will try to wrap up our comments in about 20 minutes so that we leave enough time for you guys to ask questions.
# If time is not  enough, please feel free to reach out to us through e-mail and I willtry to answer all your                 questions to the best of my abilities.
# Mr.
# Joseph will now hand it over to Mr.
# Mahendra Naredi, our CFO, to update you on our financial highlights and post which we will open it up for Q&A.
# The call is expected to last for about 60 minutes, with a maximum of 20 minutes for questions and answers.
# For confidential support call the Samaritans on 08457 90 90 90 or visit a local Samaritans branch, see www.samaritans.org for details.
# In the U.S., call the National Suicide Prevention Line on 1-800-273-8255 or visit http://www.suicidepreventionlifeline.org/.
# The acquisition of Walter Pack India has opened up a plethora of new opportunities for us.
# With this acquisition, we have penetrated deeper in passenger vehicles and consumer appliances segment.
# According to SJS Q1 FY24 pro forma, which includes Walter Pack, 36% revenue contribution would be from two wheelers,   Sriram and Maruti.
# We now strongly believe  that to strengthen our market leadership in the aesthetic business, inorganic acquisitions will  continue to be our core strategy going forward.
# We have gained more confidence in our execution capabilities of acquiring and integrating companies that could take SJS to the next level of growth.
# The acquisition of Exotech and the robust performance we delivered there in the last two years has given us more confidence.
# We are now confident that we can continue to grow our business at a faster rate than our competitors.
# We believe that we are well-positioned to compete with the likes of Tata and Mahindra in the Indian automotive industry.
# Exotech and Walter Pack acquisition have helped us to balance our portfolio concentration.
# 36% from passenger vehicles and 28% from consumer appliances and others.
# Roy Mathew, one of the founders of Walter Pack India will continue to spearhead Walter Pack with 10% stake.
# This will ensure seamless integration in the short term and harnessing optimum revenue synergies in the medium term.
# I am excited and eagerly looking forward to see how SJS grows multi-folds in the future with all the synergies and cross-selling opportunities playing out amongst the three companie.
# I would also like to highlight that Roy Mathews will also remain at the helm of the Walter Pack business in India for the next few years.
# This is a very exciting time for SJS and I am looking forward  to seeing how the three companies will work together in the long-term.
# I will also highlight that SJS will have a strong presence in the Indian automotive and consumer appliances market in the coming years.
# Walter Pack Q1 witnessed a strong                 revenue growth of 21% YoY and a robust margin performance with EBITDA margins around                 31.5%.
# Please note that for FY24 only nine months financials of Walter Pack India will be                 consolidated with SJS financials.
# With that said, I would like to now hand over the call to Sanjay to take you’ll through some of the business and industry highlights for the quarter.
# Sanjay Thapar: Yes.
# Very good morning                 everyone.
# Thank you, Joe, for updating our investors and analysts on Walter Pack.
# We have seen a robust start to FY24 financial year as we yet again outperformed the automotive                 industry for the 15th consecutive quarter.
# Consolidated revenues, that is SJS plus Exotech                 together grew by 13.6%YoY on the back of strong 18.6 per cent YoY growth in the automotive segment.
# The automotive segment has grown well for us both in the domestic market at 14.2% YoY and exports market at about 120.7% YoY.
# In Q1 FY24, we generated Rs.77.1 million in cash flows, taking total cash and cash equivalents                 to Rs.2,849.7 million, as of 30th June.
# We added two marquee customers to our already large portfolio, Toyota Tsusho and Autoliv.
# SJS has been consistently growing ahead of the industry and this quarter is no different.
# The company witnessed passenger vehicle segment growth of 24.6% on YoY ��basis while the industry production v.
# s combined grew by 1.3%.
# SJS consolidated two wheeler sales                 grew by 15% in Q1, while the two-wheeler industry production grew 1.
# 3% Yoy while SJS Consolidated two wheelers sales                  grew by 15%.
# consolidated SJS sales grew by 13.6% year-on-year.
# Automotive that is two wheeler plus                 passenger vehicle industry production grew only 2.3% YoY, while SJS witnessed a robust growth of 18.6%.
# The increase in export revenue this quarter is largely due to winning new businesses with our  preexisting customers in South America and EMEA.
# Our exports initiatives are playing out steadily.
# Appointing sales agents in South American, is helping us to strengthen our presence in that reg.
# olume grew by 7% in the first quarter of this year, compared to the same period last year.
# The increase was partly impacted due to geopolitical issues in Europe and also macroeconomic slowdown in North                 America.
# However, I would like to inform you that we are seeing improvement in the export markets and our export revenue almost doubled for the quarter compared to last year same quarter which was                 impacted by macroeconomic issues.
# We intend to hire more such agents in North America and Europe as well to grow exports.
# We continue to expand our wallet share by winning new businesses from key customers like Mahindra, TVS, Visteon, Hyundai, Bajaj Auto Continental, Honda Motorcycles & Scooters amongst others.
# On the CSR front, we've been supporting the paraplegic climber, Mr.
# Manikandan, since the past seven years and year-after-year, he's been winning medals and laurels in this field, making India proud.
# We sponsored him for the IFSC Para Climbing World C C this quarter too, and he won a gold medal in the event.
# We are seeing gradual pickup in demand in North American and Europe.
# This bounce back in export                 revenue will definitely help us grow further and it reinstates our belief that exports will be one                 of the core growth drivers for our company in the future.
# It is a great time to be a SJS employee.
# We also extended coverage of our Swachh Bharat initiative of garbage cleanup to 5 more surrounding villages, taking the total count to 12 villages.
# These initiatives make us feel very proud that our CSR initiatives are bringing about a definitive change and creating a positive impact in the society.
# I would now like to hand over the call to Mahendra – our CFO to update you on the SJS’ financial                  performance before I talk to you about the future growth.Mahendra Naredi: Thank you, Mr.
# Thapar.
# Good morning, everyone.
# Moving to slide 12, which talks about our  proprietaryfinancial performance in detail.
# As you all know, consolidated revenue at Rs.1,172.5 million has grown at 13.6% YoY on the back of strong growth in  Rural development around the country.
# Over to you Mahenda, over to you.
# The SJS board is very proud of the achievements of our team.
# SJS witnessed 14.2% YoY growth in automotive segment.
# Domestic sales outperformed the underlying automotive industry growth.
# Exports during this quarter grew by 90.8% on YoY basis on account of new business wins and gradual export market recovery.
# Q1 FY24 export constitute 11% of consolidated sales compared to 6% of the sales last year, that was impacted due to external geopolitical and macroeconomic factors.
# EBITDA at Rs.313.8 million grew 12.8%, while PAT at £.180 million grew 11.1% and PAT margin stood at 15.4%.
# Our ROCE during the quarter grew to 9.9%, up from 7.9% in Q4 2013.
# The company is now valued at over $1.5 billion.
# It is expected to be valued at $20 billion by the end of the year, up from $16 billion in Q1 2013, when it was valued at around $17 billion.
# SJS' cash and cash equivalent were at Rs.2,849.7 million at the end of June '23.
# Post Walter Pack India acquisition, it was at £461.7million.
# SJS' net debt post-acquisition has increased to Rs.539.8 million.
# Equity share capital has increased                  to Rs.310.38 million post preferential allotment to our promoter Mr.
# Joseph.
# Now his overall shareholding has increased from 15.5% to 16.9%.
# From Q2 onwards, WPI financial will be consolidated with the SJS financial numbers, on the basis our 90.1% holding in Walter Pack.
# WPI numbers are not reflected in that consolidated financial for this quarter, but they will be reported for Q2 from next quarter.
# Walter Pack has kicked off the year with a strong start, with a net profit of Rs.1.2 billion in the first quarter of 2014-15.
# The company's market value is estimated to be around Rs.
# 2.5 billion.
# The market value of SJS Enterprises is estimated at about Rs.
# 1.1 billion.
# Pro forma revenue for Q1 FY24 would have been Rs.1,528.7 million, a YoY growth of 48.2%.
# Pro forma EBITDA margin were at 27.3%, witnessing 120 bps margin expansion.
# This would result in a PAT growth of 52.1% and EPS growth of 51.8% YoY.
# We are confident of achieving our growth target in the medium term on back of cross selling opportunities, synergies between all the three businesses and growing economies of scale.
# I would now like to hand over the call back to Mr.
# Thapar to talk about our future plans and  hypertrophicgrowth outlook.
# Mr.
# Thapar, we would like to thank you for joining us on the call.
# We look forward to speaking with you again in the future.
# We hope to hear from you in the coming days.
# Back to Mail Online home.
# back to the page you came from.
# The page you were from.
# Exotech has deferred its chrome plating capacity expansion CAPEX plan by a year to calendar year '24.
# The company is revising its expansion plans to align more effectively with the evolving business requirements of both Walter Pack and Exotech.
# The rework aims to create a more conducive strategy that can accommodate the changing needs  and demands of both companies.
# Both plants are in close proximity at Ranjangaon, Pune, and the company has chartered out an alternate plan so that it can accommodate both companies' needs and demands in the long term.
# The new strategy is expected to be in place by the end of the year, with a view to being fully operational by end of 2015.
# The expansion plans will be in line with the company's organic growth strategy, which is helping the company outperform the underlying industry growth rates, the company said.
# It added that post the Walter Pack acquisition, we see many synergies between the two companies, Exotech and Walter Pack.
# d, we are absolutely on track in executing our organic growth strategy.
# Exotech growth does not get hampered in the short run.
# We are increasing capacity at Exotech by debottlenecking, utilizing our underutilized capacities in painting, etc.
# It is our consistent focus on innovation that has enabled us to stay ahead of the curve and be a preferred supplier to most of our customers.
# SJS has already started accelerating its efforts to increase its value in both two-wheeler, and passenger vehicular industries.
# For the period FY24 to 26, we maintain our stance of 20% to 25% organic growth.
# We have recently  bagged a large order for painting as well at ExTech from a large passenger vehicle OEM.
# At Exotech, we are also partnering with external chrome plating suppliers to utilize the                 excess capacity creating a win-win situation for both parties.
# At SJS, we've always focused on introduction of new premium products and technologies that are complex to manufacture and that will enable us to increase our addressable market quite significantly.
# SJS is also working on a few new age products like optical plastics and cover glass, which will further drive  up the kit value that we supply to customers.
# We are confident that even in the future, any acquisition we do, will open up a new possibility for us to achieve higher business growth and will be complementary  or an extension to our existing businesses.
# We believe we will continue to outperform the  underlying industry growth, recovery in the consumer sector in the export markets will help us accelerate this momentum of our growth trajectory even further.
# We can see that growth playing out with the addition of chrome plated parts through Exotech and IML, IMD and IMF parts through the recent Walter Pack acquisition.
# Our inorganic growth through Walter Pack will be over and above the 20% - 25%  of our organic growth through the past few years.
# We will be looking to make more acquisitions in the automotive interior space in the near future.
# SJS will continue to deliver on its robust financial and operational guidance of FY24 with 50% YoY growth in the SJS consolidated revenues and a consolidated PAT growth of about 40% YoY.
# With the addition of Walter Pack revenues and robust margin profile in our existing businesses.
# This of course will be post consolidating at 90.1% stake in Walter Pack for a nine month period  in this financial year.
# With that said, I come to an end of my quarterly updates.
# Thank you and we are now open to answer any questions that you would have.
# The question-and-answer session will now begin.
# The first question is from the line of Amit Hiranandani from SMIFS Limited.
# Please go ahead.
# Amit, your question is: What was the contribution from new products in the consolidated revenue and what was it in FY23? Mahendra Naredi: The contribution for this quarter was around 10% and it was around  20% for the whole of FY23.
# Exotech will continue to perform 14% to 15% sustainable margin.
# We hope to increase our exposure to export customers where margins would be higher.
# To be conservative, we are still maintaining our guidance about 14%  - Amit Hiranandani, CEO, SJS Enterprises.
# The company's annual results will be announced on July 27, 2023.
# For confidential support on suicide matters call the Samaritans on 08457 90 90 90, visit a local Samaritans branch or see www.samaritans.org for details.
# In the U.S.
# call the National Suicide Prevention Line on 1-800-273-8255 or visit http://www.suicidepreventionlifeline.org/.
# In the UK call the helpline on 0800- Samaritans on 08457 909090, or for confidential support call on 0800 909090.
# In the Middle East call the call is on 08457 911090, and in the UK call the 08457 809090 or  for confidential support, call the 0800 111 111.
# Devanshi Dhruva: "We've already improved margins by around 300 bps and last year it was around 15%.
# We hope to continue this and 14% to 15% right now we feel would be sustainable margins at least in the  autoimmune medium term" Amit Hiranandani: "Next on the Exotech's new plant capacity expansion, I just missed the initial comment.
# Can you please brief me a little more on this thing because what we're expecting is by FY24 end, the plant  should be ready, but I think it is delayed by one year" Sanjay Thapar: "It's not delayed, it's a conscious decision on our part, because when we guided you on                 expansio" "We feel that this could                  improve.
# - 15% EBITDA margins                  on a sustainable basis for the next 2-3 years.
# Beyond that, of course, we feel that  the plant could be ready by the end of FY24" Devanshi Dhruva: "We see a very robust demand coming in by cross selling Exotech products to existing                 SJS customers.
# To meet that demand we planned a CAPEX.
# Now, what we found is a more                 innovative frugal way to increase capacity by debottlenecking" "Our paint shop at Exotech was                 underutilized, which we are now using and we have also won businesses so that will increase                 sales without the need for chrome plating capacity," he said.
# "We just deferred that investment by one year as                 I said in my commentary and we will now try and grow this," he added.
# "If                 We want to be more effective and be very frugally with our investment.
# If                 This inve this inve inve if                 It's a good time for us to be in this business.
# We're in a very good position to grow," he concluded.
# Devanshi Dhruva: For this year FY24, SJS would be somewhere around 10-12 crores.
# Exotech would be another 10- 12 crores and Walter Pack for the next nine months would be around 10 crore.
# Overall CAPEX for this year would be between Rs 34 - 35 crores, he said.
# The conference call will be webcast on July 27, 2023, at 9am.
# For confidential support call the Samaritans on 08457 90 90 90, visit a local Samaritans branch or click here for details.
# In the U.S.
# call the National Suicide Prevention Line on 1-800-273-8255.
# In India, contact the National suicide Prevention Lifeline at 1-844-788-7255.
# For the confidential support on suicide matters call the helpline on 1800- 802-9090 or visit http://www.suicidepreventionlifeline.org/.
# In the UK, call the suicide prevention line on 0800-988-9255.
# Mahendra Naredi: We believe that it will not impact our margins.
# The raw material cost Is going up.
# But at the same time, the manufacturing, the admin and employee cost will not increase to that extent.
# At the PAT level, we believe that our PAT will go up because we ascistwill not have depreciation.
# And it is not that we are postponing the CAPEX, we are only doing it more ophobicintelligently to make sure that our investments are as frugal as possible.
# We will try and maintain our 25% to 27%margins that we have guided for and that will not get impacted.
# And the second question was when you say that theCAPEX has been postponed, our old ophobicunderstanding was t.
# s, it will be negative for margins? Mahendra: We are not postponing CAPEX.
# We are just trying to extract the maximum ROC from this business.
# Devanshi Dhruva: If you will look at a consolidated basis, we will try to maintain the 25% and 27% that we've guided for.
# Sanjay Thapar: "Absolutely, we are on track.
# We are still holding those numbers" "We already have a very, very strong trajectory of customer demand for Exotech," he said.
# "Everything goes as per plan and we are very,very bullish on growth at Exotech" "The potential for revenues would have been closer to 300 crores or so," he added.
# "It's only a smarter  way of doing things," said the CEO.
# "We are still very bullish on the future of Exotech," said Mr Thapars.
# "The future of the company is very bright," said a senior executive.
# "There is a lot of potential for the company to grow," said another senior executive, "but we are still in the early stages of that process" "It is a very exciting time for Exotech, and we're looking forward to the future," said an executive, who asked not to be named, "because it's a private company." Walter Pack India has done this quarter 356 million sales turnover with an EBITDA of 31.5%.
# On the capacity side, company is currently working on 75%.
# They have two plant; one is in Pune and second is the Manesar.
# One plant is working on75% and another is  working on 65%, so average you can say 70% to 73%.
# That was the current capacity as of now for this particular company.
# The company is always referring that we will maintain our growth rate of 20% to 25% and Walter Pack will be part of that.
# We are always referring to the 20-25% growth rate that we are aiming for in the next 2-3 years.
# We will continue to invest in the company and we are looking forward to working with the team at SJS Enterprises in the long-term.
# We hope to work with them on a number of projects in the coming years, including the construction of a new manufacturing facility in the city of Pune.
# Walter Pack Spain is amongst the global benchmarks for in-mold forming and IML technologies.
# There is a trend of using IME and there is also a trend to use also electronics and inside the ambient lighting of the car.
# In fact, this year you will see, I will not name the customers because these projects are under development, but we will see a lot of cars from mega passenger vehicle OEMs in India which will have these new generation technologies coming in.
# So while on an overall consolidated  autoimmunelevel, we have guided that we will grow.
# the current financial year.
# Sanjay Thapar:                  "It just puts SJS into another                 trajectory.
# The in- mold forming technology that Walter Pack has, they have very strong                 knowledge on tooling and in fact there are very few companies in the world which has that                 expertise" - Sanjay Thapsar, CEO of SJS.
# Devanshi Dhruva: For FY24, as we have guided last time also, overall consol growth including WPI will be                 50%.
# So you can interpret the growth with that because organic growth of SJS and Exotech                 together, as Sanjay mentioned will be 20% to 25%.
# And Walter Pack also                 will grow at that.
# This year they'll grow a little faster because they address also a consumer                 durable segment.
# And overall, I would like you to think of us as an entity that has an end-to-end                 solution for all aesthetic parts and Walter Pack is going to actually help us introduce a lot of new                 technologies to the customers in India and overseas.
# So, I think the growth path is extremely                 positive for Walter Pack.
# The next question is from the line of Mr.
# Ronak Mehta from JM Financial.
# Please go ahead with your question.
# The question is on the opportunity areas for cross selling from the existing business.
# K.A.
# Joseph: We have a cross selling opportunity between two companies.
# And also Walter Pack has won a lot of new order.
# We don't want to name the customer here, worth about 30 to 40 crores for FY25.
# So this year maybe we would get about Rs 12 to 13 crores out of that.
# And consumer business will also grow by almost about 50% for FY24.
# And because of that, the content per  vehicle is also increasing, which will impact our overall sales as well for SJS.
# SJS Enterprises was a tier-2 supplier earlier,  now becomes tier-1 post WPI acquisition.
# The company is based in Kolkata, West Bengal, and has offices in Mumbai, Bangalore and Pune.
# For confidential support on suicide matters call the Samaritans on 08457 90 90 90, visit a local Samaritans branch or click here for details.
# For more information, visit www.samaritans.org or go to their website.
# IML and IMD technology that we have to offer, IME will piggyback on this, will find a lot of demand when the customer sees this.
# So at the moment we are working on some development projects  which I think are very exciting technologies.
# So cross selling to two wheeler customers and cross selling to our large consumer appliance customers.
# So I see the synergy playing out extremely well in terms of how  burgeoning growth at Walter Pack will come plus how is the whole entity, all of it, going to be developed.
# I think the IML                 and IMDTechnology that we can offer will find  demand when the customer see this.
# We are in the process of telling them what we could do with                 IML technology that could improve aesthetics, especially for the plastics forming assemblies of                 Bajaj, Royal Enfield, Honda etc.
# So both for the EV segment and for the conventional IC engines, I think                 IME technology will be very exciting.
# There will be a lot of cross selling opportunities between Exotech and Walter Pack.
# Both companies have customers which can be used for cross-selling opportunities.
# Our strategy always has been that we take customers and we grow them into mega counts.
# Our focus as I said earlier is to prove our credentials with these global companies in the Indian market and then u.
# ese three companies working together could offer some solutions which are truly innovative, says Sanjay Thapar, CEO of Walter Pack.
# The company has added new clients, Autoliv and Toyota Tsusho, so just wanted to clarify,  will this be only for the India business or you will also export to their global plants? The answer is yes, it will be both, says Thapar and the answer is no, it won't be just for India but for the global business as well, he adds.
# The firm has also added Maruti and Tata Motors with Walter Pack as customers.
# SJS has grown because customers wanted us to grow.
# So I think we are competitive in terms of quality, cost and delivery, and that helps us win customer confidence.
# So that has been the theme and that will be the theme for both these customers as well.
# So these are let's say starting steps.
# With Autoliv, we won a large order of course for the India market.
# But then once we deliver these parts to their satisfaction, we will certainly be having a conversation with them to let's take it to global.
# se the goodwill that we've generated in Terms of capability demonstration to  purposefullypenetrate to the global network.
# So luckily for SJS,                  we've grown because customers wanted us to grow, and we've been able to meet that demand.
# And that's why we've seen a sharp jump both on YoY and QoQ basis.
# So is that only because of the outsourcing in the Exotech business or if you can throw some WPI revenue for this quarter grew 21% YoY to Rs 356 million.
# There has been a lot of talk on the IME side, that's the In-Mold Electronics.
# And I think last we talked you had mentioned that the product is still under development.
# So is there any update on that? We are happy to answer any questions you may have about the company.
# We are currently on a pre-announcement conference call for Q1 of the next fiscal year, which will be held on July 27, 2023.
# The call is expected to be webcast live from 9am to 11am.
# For confidential support, call the National Suicide Prevention Lifeline on 1-800-273-8255 or visit http://www.suicidepreventionlifeline.org/.
# In the U.S., call the Samaritans on 08457 90 90 90 or visit a local Samaritans branch, see www.samaritans.org for details.
# In the UK, contact the National suicide Prevention Line on 0800 092 9090 or click here.
# The applications are quite diverse, so we are looking at the two wheelers, we're looking at                  four Wheelers.
# Since this is a new technology that the OEMs themselves are now trying to                 evaluate.
# So we have some prototype build requirements or projects going on with a few                 customers.
# It will take time.
# So my expectation is that it would be another 2-3 years before the technology is available to the general public.
# The first phase of IME is the decorative layer, and then the functional layer which has the electronic parts.
# LEDs are going to be implanted in the functionallayer and that is going to being molded together, making it, let's say, phase-I of IMe.
# The next phase is the electronic components like ICE, which can reduce the size of the underlying PCB or connectivity with the body                 control modules used in a car.
# So all that functionality will build in.
# But since this is an entirely new technology, it will take a long time.
# We have a technology support agreement with Walter Pack Spain.
# Walter Pack will be advising us how to implement IME in the listing IML and IMF products that we have in India.
# The other part is that Walter Pack has IME technology.
# You can't compare the QoQ growth in terms of Q4 and Q1.
# Q2 and Q4 are usually stronger quarters for us due to festive season and seasonality.
# Exotech this year grew a little lower becauau of festive season and seasonal factors.
# We are looking forward to working with you in the coming months and years.
# We hope to see you at our next Investor Day on July 27, 2023.
# For more information on SJS Enterprises, please visit: www.sjse.com/investor-confirmation/sjs-enterprises-corporation-annual-presentation-and-conference-call.
# For confidential support call the Samaritans on 08457 90 90 90, visit a local Samaritans branch or click here.
# Mahendra Naredi: The farm equipment demand was soft.
# John Deere is an important customer.
# They export parts to North America.
# And of course there was some delays in launching of a new product by the sanitaryware segment, we supply to Geberit.
# So these two areas impacted a little bit the sales for this quarter.
# But the demand for Q2 remains robust and we hope to achieve our sales growth trajectory at                  Exotech which of course is very, very strong demand.
# Shrinjana Mittal: The second question is on exports.
# Like you mentioned, I think around 11% is the contribution.
# Just  wanted to see like what was it last quarter because you mentioned that the exports have grown ipientin this quarter? Mahendra: Last quarter our export was 7.9% which has now gone up to 11%.
# Devanshi Dhruva: The entire last year, if you will see because of the geopolitical issues in Europe as well as  macros economic issues in North America, exports had been impacted.
# Exports has jumped up double, about 90% growth overall, this last quarter versus the quarter a year before.
# Asia, EMEA and South America have grown well.
# North America and Europe still continue to be in the recovery mode.
# But overall we feel that we should come back to the pre-disrupt stage, says Sanjay Thapar, COO of KPMG.
# The company is targeting 20% to 25% organic growth for the year, says Shrinjana Mittal, CFO at KPMg, in addition to 20% growth from acquisitions and M&A.
# The firm is based in New York, with offices in London, Paris, Madrid and Singapore.
# The CFO says the company is in the process of setting up a new office in the U.S., which will be its first in the United States.
# The new office is expected to be open by the end of the year.
# It will be located in the San Francisco Bay Area.
# Consumer durables was a little muted growth; I would say almost about 2% - 3% and overall, as a percent of sales, it was somewhere around 15% - 16% of our sales.
# ion levels that were there last                  year… so we should come back to what we were a year ago.
# Sanjay and Devanshi, can you be a little louder?                  Ridhima Goyal, from Acquaintbee Ventures, has a question for Sanjay.
# Sanjay, please go ahead and answer the question.
# The next question is from the line of Ridhime Goyal from Acquaintship Ventures.
# Please go ahead, and ask the question that you've just been asked.
# The question is: What is the consumer durable on the overall revenue and what is the growth profile in this quarter for consumer durable segment? Sanjay: What was the growth for this quarter in the consumer durables part? The question has been asked by Ridhimesh Goyal.
# Sanjay Thapar: Consumer durables is a very important segment for us.
# We have made further inroads by                 this Walter Pack acquisition where we've added a new consumer product line to our portfolio.
# Also, on one hand, the SJS product portfolio has very bright potential because we are underpenetrated in North America as I mentioned earlier.
# So we are making inroads.
# In South America we've already seen the results.
# We will add to our feet on the ground in.
# North America  and Europe to accelerate that further.
# Plus, this new technology areas both in terms of the                 Legrand business for modular switch plates, that's also consumer busi.
# And we are also adding to our knowledge of the market in China and other Asian countries.
# We are also looking at opportunities in the Middle East, Africa and Latin America.
# And in the future, we are looking at potential opportunities in Africa and the Middle Eastern region.
# We also have opportunities in Australia and New Zealand.
# Consumer appliance business also will be significantly higher, thanks to a large proportion of Walter Pack revenues going to the consumer businesses.
# So overall, I think we will grow at about 20% - 25% as we guided earlier in terms of the mid-term growth guidance that we have given.
# Last year we added Mabe group and even IFB on our consumer appliances front.
# And those will also grow over a period of time because initially as we said that whenever                  we acquire new customers, they become our customers.
# That's what I would encourage everybody to see.
# We are now a consolidated entity.
# So our dependence on two wheelers have come down.
# Two wheelers and four wheelers now are largely similar.
# And the IML ��businesses that we could do with the likes of Whirlpool and the other appliance manufacturers.
# That in the long or the medium to long term would be very large growth drivers for our consumer appliance business.
# Almost 90% of SJS' order book is confirmed for FY24 overall.
# SJS has a smaller chunk of sales with WPI.
# But going forward, maybe  after a year or two, we'll start getting more business from them as well, says Sanjay Thapar, SJS CEO.
# The company has guided for 20% to 25% organic growth for the full year of 2023-2024.
# It has a global presence as well as customer spread also in consumer appliances, he says.
# The firm is based in Mumbai, India, but has offices in London, New York, Bangalore and Hyderabad.
# It also has a consol business with Exotech, which it bought for $1.2 billion in 2012.
# The group has a strong presence in India, with offices in Hyderabad, Mumbai, Bangalore, Chennai and Delhi.
# It is expected to expand its presence in the Middle East and Africa in the next few years.
# It will also expand in the United States and Canada.
# WPI supplies to Tata Motors and we supply to Tata                 Motors as well.
# But our content is much smaller.
# WPI are very large parts contributing almost                 about Rs.2,500 to Rs.3,500 content per vehicle.
# Our current supply from SJS just these dials that                 we supply, and of course the optical plastics part that we will do, will increase that quite well.
# So the common customers are Tata Motors,                 Mahindra for example, they don't supply too much.
# We have a large presence in Mahindra.
# So                 There are lot of cross selling opportunities that exist because we will not cannibalize the business                 if that is the question.
# And when you calculated the pro                 forma numbers, what have you considered there, if you can t help us with that? Please go ahead.
# Ap.
# ap.
# ap:                 We are happy to answer any questions you may have about WPI.
# Earlier the technical fees paid by Walter Pack was in the range of 3.5% of the sales value.
# We have agreed for a fixed amount over a period of time.
# That was not a percentage of sales, but if I say broadly on the sales, it will be around 1%.
# Walter Pack is a higher margin business, so it is margin-accretive.
# So why would the profit growth be lower than revenue growth, what am I missing here?     Sanjay Thapar: We are in a transformation stage.
# Think of it as the whole entity.
# So  this guidance for 40% PAT is on the consolidated level of all these three businesses put together.
# As I said, we are entering many new exciting areas like optical plastics, cover cover and cover products.
# We are entering a new era of growth for Walter Pack.
# It is a very exciting time for the company.
# It's a great time to be at Walter Pack and I'm looking forward to the future.
# In our last earnings call, I mentioned that we will be accelerating                 our growth footprint.
# We are not so worried about EBITDA because we have a very consistent track record.
# So any efficiency improvement that comes in is once that stabilizes.
# So our past track record if you see SJS standalone we do close to about 30% 32% of the E BITDA over the last                 five to six years and we've been steady in maintaining that.
# So these are new generation products  autoimmunerequiring in the short term, additional materials, additional testing requirement, new manpower.
# So that impacts the EBTDA to                 a certain extent in theshort term.
# We will do for the first time.
# glass, which                 we will do in the next few years, which we will call SJS Glass, which is a new product line that we are launching in the U.S.
# in the second half of next year.
# We're looking forward to seeing how that goes.
# Mahendra Naredi: The short term costs that may impact margins in the short term.
# That is what is behind the 40% guidance                 that we've done.
# Another is when we made the acquisition                 of Walter Pack, we have taken the loans for that.
# So there will be interest cost on that plus our                 internal accrual or our cash balance has been used to fund this acquisition which was earlier                 generating income and now this income will be very negligible income in FY24.
# So all three                 facts will make the PAT at 40% growth over last year.
# The next question is from the line of Amit Hiranandani from SMIFS Limited.
# The question is on the WPI side, if you sir can tell us more about going forward strategy in                 domestic and exports? I understand export is almost zero for WPI.
# Is there any restriction from                 WPI Spain that we can't go in certain countries? Sanjay Thapar:                  The WPI is a great acquisition for us.
# There is a technology support agreement that                 is available to us.
# We are also, as I mentioned earlier, the                 IME technology that we will ride on.
# So primarily, growth, I                 think we are very, very clear that there is going to be huge length of growth for the Walter Pack                 business going forward.
# And on the    WPI side, on the revenue target if you can give for FY24 - FY25, please?                  Sanjay Thpar:    The WPI is a great acquisition for SJS and there is a very clear understanding between us and the parent company that                  we are allowed to service the existing customers that we have.
# or we can't acquire any customers.
# And there are some areas that we                 were missing out earlier.
# I mentioned the cases of large IML, IMF parts to Whirlpool and to  Samsung.
# These are very large companies globally and we don't do any IML part with them.
# So                  That's a great growth opportunity for us moving forward.
# SJS and Exotech put together organically will be growing at a CAGR of 20% to 25%.
# Inorganic acquisitions will add to this growth.
# However, we won't be able to give any guidance in terms of Walter Pack currently because the acquisition has just got completed.
# And we will work out the details on our strategy at least for the next three to five years, says Devanshi Dhruva, CEO of SJS Enterprises.
# The acquisition will be completed on July 27, 2023, says Amit Hiranandani, COO, WPI.
# WPI is a joint venture between SJS and India's leading IT and IT equipment manufacturer, Hindustan Unilever.
# The two companies have been working together for more than a decade.
# The deal is expected to close in the next few weeks, according to the company's share price.
# The company is currently valued at around $1.5 billion, says the CEO of WPI, Aditya Agrawal.
# Devanshi Dhruva: SJS standalone can generate revenue close to Rs.200 crores.
# SJS is trying to acquire strategic customers which will of course benefit in the mid to long term.
# These customers are both domestic and export customers and it is for the existing customers  it is new technologies.
# So I talked of optical plastic, optical glass where we are adding to our management bandwidth in terms of having some subject matter experts who will support this  protections program.
# So that is what is going to be going to happen in the coming months and years.
# We will of of course have costs associated with that, but that is the way it will go for the next few years, says Sanjay Thapar, SJS' CEO and Managing Director.
# The company is also looking to expand into other verticals such as aerospace, defence, energy, finance, IT, retail, manufacturing and manufacturing, he adds.
# The firm is also planning to enter into an M&A deal with a number of international companies.
# Amit Hiranandani: From Q2 FY24, we are going to incorporate WPI in the consolidated numbers.
# Sanjay Thapar: Hero is a company that we've been pursuing.
# They like us, they visited and audited us.
# The ball is not in my court, it is in Hero's court.
# So they have to take a call as to when to start buying                 from u.
# impact.
# Vishal Khurana: My first question is, so we are almost providing the aesthetics to almost every two wheeler OEM, except for Hero.
# So what is really stopping us to onboard Hero with SJS? And who is the current                 supplier to Hero in aesthetics?                 Sanjay Thpar:                 Hero is acompany that we’ve been pursuing, they like us,.
# They visited and audit us.
# So the                 ball is not  in my court,.
# It is inHero’s court.
# Foxconn will be making electric vehicles in India and we'll be supplying                 aesthetics to them.
# They know SJS very well, they understand that we have a strong capability.
# So just                 wait-and-watch.
# So it should happen sooner than later, that's our hope.
# SJS Enterprises                  July 27, 2023                                  Vishal Khurana: "We have won a business from Foxconn, which was in the area of the  display screen of the EV.
# So they supplied to a company.
# I will not name it because the product                 is still under development, but it should start production in Q2"                  "We also discussed about that we will be entering i.
# s.
# into the market," he said.
# "We have a very strong team of people who are very experienced in the field of i.S.
# s," he added, "and we're looking forward to working with them." Sanjay Thapar: "We won a business for some decorative decals for the television industry, so that we've done" "Medical devices, of course, the possibility is in terms of displays and  overlays and  perhaps IML parts," he says.
# "We are in touch with customers  and we hope to grow that business as well," he adds.
# "Our specialty is make long lasting durable aesthetic parts.
# So the opportunity in other areas is larger," he concludes.
# "It is wait-and-watch.
# We just entered this last quarter.
# So we will examine as we have discussions with the customers to see what more is possible," says Thapars.
# "The opportunity, while that's an opportunity, we have still not                 sized to be honest, to say how large it could be," adds the company's chief executive.
# "So at the moment, we just entered the last quarter," adds Thapara.
# "And we are looking forward to the next quarter." This concludes our question-and-answer session.
# I would now like to hand the conference over to the management for closing comments.
# If any of the questions were left unanswered, please feel free to reach out to us and we'll answer it to the best of our abilities.
# Thank you for joining us and you may now disconnect your lines.
# Back to the page you came from.
# The call is being recorded and will be available for replay on JM Financial's website at www.jmfinancial.com.
# For confidential support on suicide matters call the Samaritans on 08457 90 90 90 or visit a local Samaritans branch, see www.samaritans.org for details.
# In the U.S., call the National Suicide Prevention Lifeline on 1-800-273-8255.
# In Europe, call the suicide prevention line on 0800-825-9255.
# The Samaritans can be reached on 0844-457-9090 or in the UK, the contact number for the company is 0800 0300 9090.

# %%
from google.colab import drive
drive.mount('/content/drive')
